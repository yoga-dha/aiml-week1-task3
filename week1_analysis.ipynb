# %% [markdown]
# # Student Performance Dataset Analysis

# %% [markdown]
# # Aim
#
# The aim of this project is to analyze student performance data, identify factors affecting academic performance, perform data cleaning, and generate meaningful insights using exploratory data analysis.

# %% [markdown]
# # Dataset Description
#
# This dataset contains student demographic, academic, and behavioral information. The dataset is used to study factors that influence student GPA and overall academic performance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Student_performance_data _.csv")

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %% [markdown]
# The first and last records were inspected successfully.

# %%
df.shape
# Out:
# (2392, 15)

# %% [markdown]
# The dataset contains 2392 rows and 15 columns.

# %% [markdown]
# # Dataset Summary
#
# Number of Records : 2392
#
# Number of Features : 15
#
# Target Variable : GPA
#
# Dataset Type : Student Performance Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %% [markdown]
# The dataset contains numerical and categorical features. Data types were inspected to identify possible corrections.

# %% [markdown]
# | Feature         | Type            | Description          |
# | --------------- | --------------- | -------------------- |
# | StudentID       | Identifier      | Unique Student ID    |
# | Age             | Numerical       | Student Age          |
# | Gender          | Categorical     | Student Gender       |
# | Ethnicity       | Categorical     | Student Ethnicity    |
# | StudyTimeWeekly | Numerical       | Weekly Study Hours   |
# | Absences        | Numerical       | Number of Absences   |
# | Tutoring        | Categorical     | Tutoring Support     |
# | GPA             | Target Variable | Academic Performance |

# %% [markdown]
# GPA is selected as the main performance indicator.
# StudyTimeWeekly, Absences, Tutoring, and ParentalSupport may influence GPA.

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %% [markdown]
# No missing values were found in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Duplicate records were checked to ensure data consistency.

# %%
df = df.drop_duplicates()

# %% [markdown]
# The dataset was checked for duplicates, missing values, and inconsistent labels. No major quality issues were found.

# %%
df.to_csv("cleaned_student_performance.csv", index=False)

# %% [markdown]
# A cleaned version of the dataset was saved separately.

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %% [markdown]
# Descriptive statistics were generated to understand the distribution of numerical variables.

# %% [markdown]
# # Observations
#
# 1. The dataset contains 2392 student records and 15 features.
#
# 2. No missing values were found, indicating good data quality.
#
# 3. GPA is the primary indicator of academic performance.
#
# 4. Students with higher weekly study time generally tend to achieve better GPA scores.
#
# 5. Higher absences may negatively affect academic performance.
#
# 6. Tutoring support may contribute positively to student outcomes.
#
# 7. Parental support appears to influence student performance.
#
# 8. Academic performance depends on multiple educational and behavioral factors.

# %% [markdown]
# # Conclusion
#
# The dataset was successfully analyzed and found to be clean and well-structured. Study time, attendance, tutoring, and parental support appear to influence GPA. The dataset is suitable for further analysis and machine learning applications.
